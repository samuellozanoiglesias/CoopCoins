# %%
import jax
import jax.numpy as jnp
import optax
import numpy as np
from jaxmarl.environments.switch_riddle.make_train import make_train
# Out:
# CUDA backend failed to initialize: Unable to use CUDA because of the following issues with CUDA components:
# Outdated CUDA installation found.
# Version JAX was built against: 12030
# Minimum supported: 12010
# Installed version: 12000
# The local installation version must be no lower than 12010.
# --------------------------------------------------
# Outdated cuBLAS installation found.
# Version JAX was built against: 120304
# Minimum supported: 120100
# Installed version: 120002
# The local installation version must be no lower than 120100.
# --------------------------------------------------
# Outdated cuSPARSE installation found.
# Version JAX was built against: 12200
# Minimum supported: 12100
# Installed version: 12001
# The local installation version must be no lower than 12100..(Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# Hiperparámetros
NUM_ENVS = 4
NUM_EPOCHS = 1000
SHOW_EVERY_N_EPOCHS = 10
NUM_AGENTS = 3
LR = 1e-2

# %%
config = {
    "NUM_ENVS": NUM_ENVS,
    "NUM_AGENTS": NUM_AGENTS,
    "NUM_EPOCHS": NUM_EPOCHS,
    "SHOW_EVERY_N_EPOCHS": SHOW_EVERY_N_EPOCHS,
    "LR": LR,
}

params, rewards = make_train(config)
# Out:
# Step 0:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 10:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 20:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 30:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 40:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 50:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 60:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 70:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 80:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 90:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 100:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 110:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 120:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 130:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 140:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 150:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 160:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 170:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 180:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 190:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 200:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 210:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
#
# Step 220:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 230:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 240:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 250:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 260:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 270:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 280:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 290:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
#
# Step 300:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 310:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 320:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 330:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 340:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 350:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 360:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 370:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 380:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 390:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 400:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 410:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 420:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 430:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 440:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
#
# Step 450:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 460:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 470:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 480:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
#
# Step 490:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 500:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 510:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 520:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 530:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 540:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 550:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 560:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 570:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 580:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 590:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 600:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 610:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 620:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 630:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 640:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 650:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 660:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 670:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 680:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 690:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 700:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 710:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 720:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 730:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 740:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
#
# Step 750:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 760:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 770:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 780:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 790:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 800:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 810:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 820:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
#
# Step 830:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 840:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 850:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
#
# Step 860:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 870:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 880:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 890:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 900:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 910:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 920:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 930:
#   reward[agent_0] = -1.00
#   reward[agent_1] = -1.00
#   reward[agent_2] = -1.00
#
# Step 940:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 950:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 960:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 970:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 980:
#   reward[agent_0] = 0.00
#   reward[agent_1] = 0.00
#   reward[agent_2] = 0.00
#
# Step 990:
#   reward[agent_0] = 1.00
#   reward[agent_1] = 1.00
#   reward[agent_2] = 1.00
